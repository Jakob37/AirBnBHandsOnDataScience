# %% [markdown]
# # Setup

# %%
import pandas as pd

# %%
age_gender_df = pd.read_csv('age_gender_bkts.csv')
print(age_gender_df.shape)
age_gender_df.head()
# Out:
# (420, 5)
#   age_bucket country_destination gender  population_in_thousands    year
# 0       100+                  AU   male                      1.0  2015.0
# 1      95-99                  AU   male                      9.0  2015.0
# 2      90-94                  AU   male                     47.0  2015.0
# 3      85-89                  AU   male                    118.0  2015.0
# 4      80-84                  AU   male                    199.0  2015.0

# %%
sample_submission_df = pd.read_csv('sample_submission_NDF.csv')
print(sample_submission_df.shape)
sample_submission_df.head(10)
# Out:
# (62096, 2)
#            id country
# 0  5uwns89zht     NDF
# 1  jtl0dijy2j     NDF
# 2  xx0ulgorjt     NDF
# 3  6c6puo6ix0     NDF
# 4  czqhjk3yfe     NDF
# 5  szx28ujmhf     NDF
# 6  guenkfjcbq     NDF
# 7  tkpq0mlugk     NDF
# 8  3xtgd5p9dn     NDF
# 9  md9aj22l5a     NDF

# %%
country_df = pd.read_csv('countries.csv')
print(country_df.shape)
country_df
# Out:
# (10, 7)
#   country_destination  lat_destination  lng_destination  distance_km  \
# 0                  AU       -26.853388       133.275160   15297.7440
# 1                  CA        62.393303       -96.818146    2828.1333
# 2                  DE        51.165707        10.452764    7879.5680
# 3                  ES        39.896027        -2.487694    7730.7240
# 4                  FR        46.232193         2.209667    7682.9450
# 5                  GB        54.633220        -3.432277    6883.6590
# 6                  IT        41.873990        12.564167    8636.6310
# 7                  NL        52.133057         5.295250    7524.3203
# 8                  PT        39.553444        -7.839319    7355.2534
# 9                  US        36.966427       -95.844030       0.0000
#
#    destination_km2 destination_language   language_levenshtein_distance
# 0        7741220.0                   eng                           0.00
# ...

# %%
df = pd.read_csv('train_users_2.csv')
df.date_first_booking = pd.to_datetime(df.date_first_booking)
print(df.shape)
print(df.columns)
df.head(10)
# Out:
# (213451, 16)
# Index(['id', 'date_account_created', 'timestamp_first_active',
#        'date_first_booking', 'gender', 'age', 'signup_method', 'signup_flow',
#        'language', 'affiliate_channel', 'affiliate_provider',
#        'first_affiliate_tracked', 'signup_app', 'first_device_type',
#        'first_browser', 'country_destination'],
#       dtype='object')
#            id date_account_created  timestamp_first_active date_first_booking  \
# 0  gxn3p5htnn           2010-06-28          20090319043255                NaT
# 1  820tgsjxq7           2011-05-25          20090523174809                NaT
# 2  4ft3gnwmtx           2010-09-28          20090609231247         2010-08-02
# 3  bjjt8pjhuk           2011-12-05          20091031060129         2012-09-08
# 4  87mebub9p4           2010-09-14          20091208061105         2010-02-18
# 5  osr2jwljor           2010-01-01          20100101215619         2010-01-02
# ...

# %%
print(df.gender.unique())
print(len(df.gender))
# Out:
# ['-unknown-' 'MALE' 'FEMALE' 'OTHER']
# 213451

# %%
print(df.id.nunique())
print(len(df.id))
# Out:
# 213451
# 213451

# %%
df.date_first_booking.head()
# Out:
# 0          NaT
# 1          NaT
# 2   2010-08-02
# 3   2012-09-08
# 4   2010-02-18
# Name: date_first_booking, dtype: datetime64[ns]

# %%
print(df.date_first_booking[3])
print(df.date_first_booking[4])
df.date_first_booking[3] > df.date_first_booking[4]
# Out:
# 2012-09-08 00:00:00
# 2010-02-18 00:00:00
# True

# %%
print(df.signup_method.value_counts())
# Out:
# basic       152897
# facebook     60008
# google         546
# Name: signup_method, dtype: int64

# %%
print(df.affiliate_provider.value_counts())
# Out:
# direct                 137426
# google                  51693
# other                   12549
# craigslist               3471
# bing                     2328
# facebook                 2273
# vast                      829
# padmapper                 768
# facebook-open-graph       545
# yahoo                     496
# gsp                       453
# meetup                    347
# email-marketing           166
# naver                      52
# baidu                      29
# yandex                     17
# wayn                        8
# daum                        1
# Name: affiliate_provider, dtype: int64

# %%
print(df.country_destination.value_counts())
# Out:
# NDF      124543
# US        62376
# other     10094
# FR         5023
# IT         2835
# GB         2324
# ES         2249
# CA         1428
# DE         1061
# NL          762
# AU          539
# PT          217
# Name: country_destination, dtype: int64

# %%
df['datetime'] = pd.to_datetime(df.loc[:, 'date_account_created'])
df.loc[:, 'datetime'].head()
# Out:
# 0   2010-06-28
# 1   2011-05-25
# 2   2010-09-28
# 3   2011-12-05
# 4   2010-09-14
# Name: datetime, dtype: datetime64[ns]

# %%
df.date_first_booking.head()
# Out:
# 0           NaN
# 1           NaN
# 2    2010-08-02
# 3    2012-09-08
# 4    2010-02-18
# Name: date_first_booking, dtype: object

# %%
df.head()
# Out:
#            id date_account_created  timestamp_first_active date_first_booking  \
# 0  gxn3p5htnn           2010-06-28          20090319043255                NaN
# 1  820tgsjxq7           2011-05-25          20090523174809                NaN
# 2  4ft3gnwmtx           2010-09-28          20090609231247         2010-08-02
# 3  bjjt8pjhuk           2011-12-05          20091031060129         2012-09-08
# 4  87mebub9p4           2010-09-14          20091208061105         2010-02-18
#
#       gender   age signup_method  signup_flow language affiliate_channel  \
# 0  -unknown-   NaN      facebook            0       en            direct
# 1       MALE  38.0      facebook            0       en               seo
# 2     FEMALE  56.0         basic            3       en            direct
# 3     FEMALE  42.0      facebook            0       en            direct
# 4  -unknown-  41.0         basic            0       en            direct
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
df.country_destination.value_counts().hist()
plt.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-45f817fdea93> in <module>()
#       1
# ----> 2 plt.plot(df.country_destination.value_counts().hist())
#
# /usr/local/anaconda/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3315                       mplDeprecation)
#    3316     try:
# -> 3317         ret = ax.plot(*args, **kwargs)
#    3318     finally:
#    3319         ax._hold = washold
#
# /usr/local/anaconda/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
#    1897                                   RuntimeWarning, stacklevel=2)
# -> 1898             return func(ax, *args, **kwargs)
#    1899         pre_doc = inner.__doc__
#    1900         if pre_doc is None:
#
# ...
